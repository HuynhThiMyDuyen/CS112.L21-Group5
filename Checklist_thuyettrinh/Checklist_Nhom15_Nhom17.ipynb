# %% [markdown]
# ### GIỚI THIỆU PHƯƠNG PHÁP THIẾT KẾ THUẬT TOÁN: COMPLETED SEARCH - BRUTE FORCE (Nhóm 15)
#
# 1. Khái niệm:
# * Là một thuật toán vét cạn, chạy tất cả các trường hợp có thể.
#
# 2. Dạng thuật toán phổ quát:
#
# 3. Đặc điểm:
# * Không có pha tiền xử lý
# * Quá trình so sánh thực hiện theo bất kỳ thứ tự nào
# * Độ phức tạp thuật toán là O(nxm)
#
# 4. Ưu điểm:
# * Đơn giản nhất để giải quyết vấn đề
# * Ít tốn không gian nhớ, do không dùng bộ nhớ phụ để lưu
#
# 5. Nhược điểm:
# * Tốc độ chạy thuật toán rất chậm
#
# 6. Khi nào sử dụng Brute Force
# * Dùng để đối chiếu kết quả, làm bộ test (Ưu điểm)
#
# 7. Bài tập
# * Tìm hai điểm gần nhau nhất trong tập hợp n ddieerEM trong mặt phẳng hai chiều Cartesian.(pp Vét cạn)
# * Cho 1 mảng các số nguyên gồm các số liên tiếp nhau nhưng chưa được sắp xếp.Sắp xếp mảng tăng dần
#
# >Các bài toán vân tay, có bài toán nào đẫ từng dùng Brute Force để xử lý hay không?
#
#
# <hr>
#
# ### GIỚI THIỆU PHƯƠNG PHÁP THIẾT KẾ THUẬT TOÁN: GREEDY APPROACH (Nhóm 17)
#
# 1. Khái niệm
# * Tối ưu ở từng bước ---> Tối ưu toàn bộ vấn đề
#
# 2. Phân nhóm tham lam:
# * Đặc biệt: DP, NP
# * Đồ thị: Dijkstra
# * Tiêu chuẩn
# * Mảng
# * OS
#
# 3. Cấu trúc
# quyết định lựa chọn tham lam
# Cấu trúc con tối ưu
# ==> Thuật toán tham lam
#
# 4. Ưu điểm
# * Đơn giản
# * Hiệu quả
# * Giải quyết các vấn đề tối ưu
#
# 5. Hạn chế
# * Khó xác định tính đúng đắn
# * Không tính tới các bước sau
# * Tối ưu toàn cầu không chắc chắn
#
# 6. Lưu ý: Khi nào nên tránh sử dụng thuật toán tham lam
# * Bài toán có trọng số âm
# * Bài toán mà thứ tự lựa chọn quan trọng
# * Bài toán tìm đường đi A->B trong thành phố hoặc
#
# 7. Độ phức tạp
#
# 8. Ví dụ
